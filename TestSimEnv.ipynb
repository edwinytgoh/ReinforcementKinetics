# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler
from envs.sim_env import SimEnv
import cantera as ct
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
# %%prun 
myEnv = SimEnv()
myEnv.render()
game_over = False
while not game_over:
    obs, reward, game_over, _ = myEnv.step(myEnv.action_space.sample())
    myEnv.render()
# Out:
# step	age (ms)	T	phi_norm	NO	CO	Reward	Reward T	Reward NO	Reward CO
# ...
# 0	 0.00	 300.00	 nan	 0.00	 0.00	 0.00	 -1795.48	5.00	325.00
# 1	 0.00	 1323.89	 0.32	 0.06	 1.25	 189.77	 -94.85	5.00	280.12
# 2	 0.00	 1101.70	 0.57	 0.05	 0.95	 50.47	 -244.18	5.00	290.65
# 3	 0.00	 1176.01	 0.49	 0.05	 1.06	 105.87	 -184.41	5.00	286.79
# 4	 0.00	 1182.70	 0.51	 0.05	 1.05	 110.46	 -179.55	5.00	287.01
# 5	 0.00	 1212.98	 0.48	 0.06	 1.09	 129.71	 -158.53	5.00	285.74
# 6	 0.01	 1245.48	 0.46	 0.06	 1.12	 148.87	 -137.77	5.00	284.64
# 7	 0.01	 1253.39	 0.45	 0.06	 1.13	 152.76	 -132.99	5.00	284.25
# 8	 0.01	 1270.46	 0.43	 0.06	 1.15	 161.46	 -123.02	5.00	283.48
# 9	 0.01	 1273.57	 0.43	 0.06	 1.16	 162.44	 -121.26	5.00	283.20
# 10	 0.01	 1292.21	 0.41	 0.06	 1.18	 171.44	 -111.01	5.00	282.46
# 11	 0.01	 1306.30	 0.39	 0.06	 1.20	 177.63	 -103.63	5.00	281.77
# 12	 0.01	 1306.70	 0.40	 0.06	 1.21	 177.08	 -103.43	5.00	281.50
# 13	 0.01	 1313.59	 0.39	 0.06	 1.22	 179.55	 -99.93	5.00	280.98
# ...

# %%
myEnv.action_space.high
# Out:
# array([[6.5106573e-16, 0.0000000e+00, 0.0000000e+00]], dtype=float32)
