# %%
# %matplotlib notebook 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from envs.SimUtils import sigmoid as sigm

# %%
x = np.linspace(-10,100, 10000)/100

# %%
0.9*0.5
# Out:
# 0.45

# %% [markdown]
# # Temp Reward

# %%
y = 100*sigm(-x)
y2 = 100*sigm(-(x-10))
y3 = 100*sigm(-2*(x-10))
y4 = 100*sigm(-150*(x-0.025))
y5 = 100*sigm(-250*(x-0.025))
y6 = 100*sigm(-450*(x-0.045))
plt.subplots()
plt.plot(x, y, label='y1')
plt.plot(x, y2, label='y2')
plt.plot(x, y3, label='y3')
plt.plot(x, y4, label='y4')
plt.plot(x, y5, label='y5')
plt.plot(x, y6, label='y6')
plt.grid()
plt.xlim((0, 0.06))
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
T_eq = 1979
T_max = 300
T_distance_percent = np.abs(T_eq - T_eq)/T_eq
T_threshold_percent = 0.9*0.005 # +-10K for 1975K 
reward_T = 100*sigm(-T_threshold_percent*1000*(T_distance_percent - T_threshold_percent))
reward_T
# Out:
# 50.50623270119764

# %%
T_eq * 0.05
# Out:
# 98.95

# %%
T_threshold_percent = 0.02
T_distance_percent = np.linspace(0, 1, 1000)
y = 200*sigm(-350*(T_distance_percent - T_threshold_percent))
plt.subplots()
plt.plot(T_distance_percent, y)
plt.axvline(x=T_threshold_percent, color='red')
plt.grid()
plt.xlim((0, 0.1))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 0.1)

# %% [markdown]
# # CO Reward

# %%
plt.subplots()
x = np.linspace(0, 1000, 10000)
y = 100*sigm(-3*(x-30))
y2 = 100*sigm(-3*(x-32))

plt.plot(x, y, label='y1')
plt.plot(x, y2, label='y2')
plt.grid()
plt.xlim((20, 35))
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # NO Reward

# %%
plt.subplots()
x = np.linspace(0, 1000, 10000)
y = 200*sigm(-(x-25))
y2 = 200*sigm(-0.4*(x-15))
y3 = 500*sigm(-0.4*(x-15))


plt.plot(x, y, label='y1')
plt.plot(x, y2, label='y2')
plt.plot(x, y3, label='y3')
plt.grid()
plt.xlim((0, 35))
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Reactant Reward

# %%
plt.subplots() 
x = np.linspace(0,100,1000)
y1 = (100 - x)
y2 = np.square(y1)
y3 = np.exp(y1)
y4 = 200*sigm(-0.2*(x-40))
y5 = (1000 - 20*x)
# y6 = (10000 - 1e-3*(x**4))
y7 = 200*sigm(-0.2*(x-40))
plt.plot(x, y1, label='y1')
# plt.plot(x, y2, label='y2')
# plt.plot(x, y3, label='y3')
plt.plot(x, y4, label='y4')
plt.plot(x, y5, label='y5')
# plt.plot(x, y6, label='y6')
# plt.plot(x, y5, label='y7')
# plt.yscale('log')
plt.grid()
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
