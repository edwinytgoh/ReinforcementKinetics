# %%
# %matplotlib notebook 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from envs.SimUtils import sigmoid as sigm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-cecd25983816> in <module>
#       3 import seaborn as sns
#       4 import numpy as np
# ----> 5 from envs.SimUtils import sigmoid as sigm
#
# ~/Documents/ReinforcementKinetics/envs/SimUtils.py in <module>
#       1 import os
#       2 import pandas as pd
# ----> 3 import cantera as ct
#       4 import numpy as np
#       5 from numba import jit
#
# ModuleNotFoundError: No module named 'cantera'

# %%
x = np.linspace(-10,100, 10000)

# %%
y = sigm(-x)
y2 = sigm(-(x-10))
y3 = sigm(-2*(x-10))
y4 = sigm(-20*(x-0.25))
y5 = 100*sigm(-15*(x-0.25))

sns.lineplot(x, y, label='y1')
sns.lineplot(x, y2, label='y2')
sns.lineplot(x, y3, label='y3')
sns.lineplot(x, y4, label='y4')
sns.lineplot(x, y5, label='y5')
plt.grid()
plt.xlim((0, 0.6))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 0.6)
